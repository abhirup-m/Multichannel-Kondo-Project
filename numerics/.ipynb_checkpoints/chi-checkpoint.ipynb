# %%
import numpy as np
from qutip import *
from tqdm import tqdm
from multiprocessing import Pool
import matplotlib
from math import factorial
from matplotlib import pyplot as plt
plt.rc('font', size=30)          # controls default text sizes
plt.rc('xtick', labelsize=30)    # fontsize of the tick labels
plt.rc('ytick', labelsize=30)    # fontsize of the tick labels
plt.rc('legend', fontsize=30)    # legend fontsize
plt.rc('lines', markersize = 10)

matplotlib.rcParams['text.usetex'] = True
plt.rcParams["figure.figsize"]= 16, 10
plt.rcParams['figure.dpi'] = 70
matplotlib.rcParams['lines.linewidth'] = 4
plt.rcParams['axes.grid'] = False
plt.rcParams['axes.grid.which'] = "both"
props = dict(boxstyle='round', alpha=0.01)
# Out:
# /home/abhirup/.local/lib/python3.9/site-packages/qutip/configrc.py:326: UserWarning: Invalid qutip config variable in qutiprc: num_cpus
#   warnings.warn("Invalid qutip config variable in qutiprc: "

# %%
def ham(J,K,h1,h2):
    sz = sigmaz()/2
    sx = sigmax()/2
    sy = sigmay()/2
    H = 0
    for ch in range(K):
        H += J*tensor([sx] + [identity(2)]*ch + [sx] + [identity(2)]*(K-ch-1))
        H += J*tensor([sy] + [identity(2)]*ch + [sy] + [identity(2)]*(K-ch-1))
        H += J*tensor([sz] + [identity(2)]*ch + [sz] + [identity(2)]*(K-ch-1))
        H += h2*tensor([identity(2)]*(1+ch) + [sz] + [identity(2)]*(K-ch-1))
    H += h1*tensor([sz] + [identity(2)]*K)
    return H

# %%
def get_Z(J,K,h1,h2,T):
    beta = 1/T
    H = ham(J,K,h1,h2)
    E = H.eigenenergies()
    Z = np.sum(np.exp(-beta*E))
    return Z


def get_chi_num(J,K,T_range,delta=[0.00001, 0]):
    h2 = 0
    h1 = 0
    chi = []
    for T in T_range:
        Z = get_Z(J,K,h1,h2,T)
        Z_plus_deltaZ = get_Z(J,K,h1+delta[0],h2+delta[1],T)
        Z_plus_2deltaZ = get_Z(J,K,h1+2*delta[0],h2+2*delta[1],T)
        dZdh = (Z_plus_deltaZ - Z)/(sum(delta))
        d2zdh2 = (Z_plus_2deltaZ + Z - 2*Z_plus_deltaZ)/(sum(delta)**2)
        chi.append(T * (d2zdh2/Z - (dZdh/Z)**2))
        print (Z, dZdh, d2zdh2)
    return np.array(chi)

# %%
def get_chi_exact(J,K,T_range):
    M_max = K/2
    M_min = 0 if K%2 == 0 else 1/2
    M_range = np.arange(M_min, M_max+0.1)
    C_M = np.array([factorial(K-1)/(factorial(int(K/2 - M))*factorial(int(K/2 - 1 + M))) for M in M_range])
    chi = []
    for T in T_range:
        beta = 1/T
        Z = np.sum(C_M * (4*np.exp(beta*J/4) * M_range * np.cosh(beta*J*(M_range+1/2)/2) + 2*np.exp(-beta*J*M_range/2)))
        Zpp = 0
        Sigma = np.array([np.sum((np.arange(-M, M-1+0.1) + 1/2)**2) for M in M_range])
        theta = (beta*J/2)*(M_range + 1/2)
        Zpp += (beta**2 / 2)*np.sum(C_M * np.exp(-beta*J*M_range/2))
        Zpp += (beta**2 * np.exp(beta*J/4) / 2) * np.sum(C_M * (2*M_range*np.sinh(theta) + (beta**2 * J**2 / 4)*Sigma*(np.cosh(theta)/theta - np.sinh(theta)/(theta**2)))/theta)
        chi.append(T * Zpp/Z)
        # print (Z, Zpp)
    return np.array(chi)


def get_chi_exact2(J,K,T_range):
    M_max = K/2
    M_min = 0 if K%2 == 0 else 1/2
    M_range = np.arange(M_min, M_max+0.1)
    # C_M = np.array([factorial(K-1)/(factorial(int(K/2 - M))*factorial(int(K/2 - 1 + M))) for M in M_range])
    chi = []
    for T in T_range:
        beta = 1/T
        Z = Zp = Zpp = 0
        for M in M_range:
            C_M = factorial(K-1)/(factorial(int(K/2 - M))*factorial(int(K/2 - 1 + M)))
            Z += 2 * C_M * np.exp(-beta*J*M/2) 
            Zpp += 2 * C_M * beta**2 * M**2 * np.exp(-beta*J*M/2)
            m_range = np.arange(-M, M)
            for m in m_range:
                phimM = (J/4)*np.sqrt(M*(M+1) - m*(m+1) + 1/4)
                Z += 2*C_M*np.exp(beta*J/4)*np.cosh(beta*phimM)
                Zp -= 2*C_M*np.exp(beta*J/4)*beta*m*(np.cosh(beta*phimM) + J*np.sinh(phimM)/(4*phimM))
                Zpp += 2 * C_M * np.exp(beta*J/4) * beta**2 * ((m**2  + (J*m/(4*phimM))**2)* np.cosh(beta*phimM) + (J*m**2/(2*phimM) - J*m/(16*phimM**3)) * np.sinh(beta*phimM))
        chi.append(T * (Zpp/Z - (Zp/Z)**2))
        # print (Z, Zpp)
    return np.array(chi)

# %%
T_range = 10**np.linspace(-2.7, 0, 100)
K = 4
J = 1
cols = ['r', 'b', 'g', 'y']
for K in range(1,5):
    cols = [cols[-1]] + cols[:-1]
    J = 1/K
    chi_ex = get_chi_exact(J,K,T_range)
    chi_num = get_chi_num(J,K,T_range,delta=[0.00001, 0])
    plt.scatter(T_range, chi_ex, marker='.', color=cols[-1], label=r"(analytical)$K={}$".format(K))
    plt.plot(T_range, chi_num, color=cols[-1], lw = 1, label=r"(numerical)$K={}$".format(K))

# # plt.plot(T_range, 1/T_range, ls="--")
plt.title(r"$J = 1/K$")
plt.xscale("log")
plt.yscale("log")
plt.ylabel("$\chi_\mathrm{imp}$")
plt.xlabel(r"temperature")
plt.legend()
# plt.savefig("chi_mchannel.pdf", bbox_inches='tight')
plt.show()

# %%
K_range = np.int64(10**np.linspace(0,3,1000))
Sigma_max = np.array([np.sum((np.arange(-K/2, K/2-1+0.1) + 1/2)**2) for K in K_range])
plt.plot(K_range, Sigma_max/(K_range*(K_range+1)**2))
plt.axhline(1/12,0,1, ls="--")
plt.xscale("log")

# %%
T_range = 10**np.linspace(-3, -2, 10)
K = 4
J = 2
cols = ['r', 'b', 'g', 'y']
for K in range(2,5):
    cols = [cols[-1]] + cols[:-1]
    J = 1/K
    chi_ex = get_chi_exact2(J,K,T_range)
    chi_num = get_chi_num(J,K,T_range, delta=[0,0.0001])
    # plt.scatter(T_range, chi_ex, marker='.', color=cols[-1], label=r"(analytical)$K={}$".format(K))
    plt.scatter(T_range, T_range*chi_num, marker=".", color=cols[-1], lw = 2, label=r"(numerical)$K={}$".format(K))
    S = np.sum((np.arange(-K/2, K/2) + 1/2)**2)
    phi = J*(K+1)/2
    plt.axhline(S*(K+3)**2 / (K*(K+1)**2), 0, 1)
    # print ((S*(K+3)**2 / (K+2)**3)/(T_range*chi_num)[0])

# # plt.plot(T_range, 1/T_range, ls="--")
plt.title(r"$J = 1/K$")
plt.xscale("log")
plt.yscale("log")
plt.ylabel("$\chi_\mathrm{imp}$")
plt.xlabel(r"temperature")
plt.legend()
# plt.savefig("chi_mchannel.pdf", bbox_inches='tight')
plt.show()
# Out:
# 2.807184435705675e+217 6.248834478926302e+218 1.252563684487615e+223
# 2.693099869856317e+168 3.5946963970871536e+169 7.199054842624949e+173
# 3.001794422854026e+130 2.4029641465490197e+131 4.809809490746138e+135
# 1.235523131684532e+101 5.932702988638157e+101 1.1871168389719194e+106
# 2.186261739986306e+78 6.2983993683020145e+78 1.2600481008773521e+83
# 5.29102353098917e+60 9.147551842566438e+60 1.8298326451185199e+65
# 1.2133465811292186e+47 1.2592912647829617e+47 2.518850276028452e+51
# 3.3371284536400514e+36 2.080017919180245e+36 4.160303223248804e+40
# 2.2216448111468027e+28 8.320465345480751e+27 1.6641578865820412e+32
# 1.0369411057174144e+22 2.3350469625852723e+21 4.6702044748185596e+25
# 2.711161452708748e+181 1.41475404965919e+183 2.85167703875999e+187
# 3.844205898598048e+140 1.2021516677444026e+142 2.415595320856592e+146
# 9.065958227153038e+108 1.6994415599886484e+110 3.408455324959728e+114
# 2.947623377871928e+84 3.312740101266885e+85 6.63667240106938e+89
# 3.2310825501068604e+65 2.1774879058519877e+66 4.359389815065533e+70
# 6.748584174310618e+50 2.7275945393609694e+51 5.458507608415828e+55
# 2.9034675992468306e+39 7.039092408989135e+39 1.408332688293416e+44
# 4.5962858289032396e+30 6.685369845266871e+30 1.3373673321628808e+35
# 7.054914920170847e+23 6.15793638528558e+23 1.231749693317736e+28
# 3.73873500389734e+18 1.95896718501888e+18 3.91824515237888e+22
# 2.9006191177623035e+163 2.6179212670745617e+165 5.313403946328735e+169
# 5.000078684912498e+126 2.7029470005320895e+128 5.45385584563766e+132
# 1.7152333187901476e+98 5.556011973264844e+99 1.1171100937662522e+104
# 1.567384887852486e+76 3.04308846458348e+77 6.105573353213903e+81
# 1.3522721708279612e+59 1.5739301447721494e+60 3.15387564435332e+64
# 8.297404534020369e+45 5.790434941673584e+46 1.1594142492313721e+51
# 4.889631694377371e+35 2.0462148153196594e+36 4.095243249069364e+40
# 5.872421068561824e+27 1.4738684173672887e+28 2.9489528843936287e+32
# 4.3280625438127387e+21 6.515834980180951e+21 1.3034896752702915e+26
# 7.72868292470075e+16 6.980690220544e+16 1.396345614768e+21

# %%
M = 6
m = np.arange(-M, M)
print (sum((m+1/2)**2))
# Out:
# 143.0
